# %% [markdown]
# Which authors have consistently appeared in top rankings?

# %% [markdown]
# Description- I will be using the data given to amwser this question using pattern recognization and
# name searching to see the top 3 authors that appeared the most in the data set. This project uses an **observational study** design because I am analyzing
# existing data without manipulating any variables. The dataset consists of a **sample**
# of books collected from the 'books.csv'
# file, which includes information such as author names, user ratings, and publication years.
#     The data appears to represent
# popular books over a certain period but does not cover every book ever published, making it a
# sample rather than the entire population of books.
#
# The data was collected from an online source (e.g., a book sales or rating website),
# although the exact collection method is not specified in the dataset. Since this is secondary data,
# I did not control the data collection process.
#
# One potential bias in this study is **selection bias**: the dataset likely overrepresents popular
# or bestselling books,
# which means authors with many niche or less popular titles may not appear frequently. Additionally,
# the data may be skewed towards books published
# in specific years or genres, affecting which authors appear most often.

# %%
import pandas as pd
df = pd.read_csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data
df = pd.read_csv('books.csv')

# Calculate average User Rating grouped by Year
avg_rating_by_year = df.groupby('Year')['User Rating'].mean()

# Plot the average User Rating over the years
plt.figure(figsize=(10,6))
avg_rating_by_year.plot(kind='line', marker='o', color='purple')
plt.title('Average User Rating by Year')
plt.xlabel('Year')
plt.ylabel('Average User Rating')
plt.grid(True)
plt.show()

# %%
import pandas as pd

# Load data
df = pd.read_csv('books.csv')

# Count how many times each author appears
author_counts = df['Author'].value_counts()

# Get the top 3 authors
top_3_authors = author_counts.head(3)

print("Top 3 authors by number of books:")
print(top_3_authors)
# Out:
# Top 3 authors by number of books:
# Author
# Jeff Kinney        12
# Rick Riordan       11
# Suzanne Collins    11
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

top_3_authors.plot(kind='bar', color='orange')
plt.title('Top 3 Authors by Number of Books')
plt.xlabel('Author')
plt.ylabel('Number of Books')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Use a font with wide unicode support
plt.rcParams['font.family'] = 'DejaVu Sans'

# Load data
df = pd.read_csv('books.csv')

# Clean author names: remove non-ASCII characters
df['Author'] = df['Author'].apply(lambda x: x.encode('ascii', errors='ignore').decode('ascii'))

# Count appearances of each author and get top 20
author_counts = df['Author'].value_counts().head(20)

# Create horizontal bar plot
plt.figure(figsize=(12, 8))
author_counts.sort_values().plot(kind='barh', color='skyblue')
plt.xlabel('Number of Appearances')
plt.title('Top 20 Authors by Number of Appearances in the Dataset')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Load data
df = pd.read_csv('books.csv')

# Count how many times each author appears
author_counts = df['Author'].value_counts()

# Get top 3 authors
top_3_authors = author_counts.head(3)

# Format authors into a nice string
authors_str = ', '.join(top_3_authors.index[:-1]) + f", and {top_3_authors.index[-1]}"

# Create the sentence
sentence = f"The most frequently appearing authors in this dataset are {authors_str}, reflecting their consistent presence and popularity over the analyzed period."

print(sentence)
# Out:
# The most frequently appearing authors in this dataset are Jeff Kinney, Rick Riordan, and Suzanne Collins, reflecting their consistent presence and popularity over the analyzed period.
