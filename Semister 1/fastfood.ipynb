# %% [markdown]
# How many average stars in yelp reviews does McDonald's have in comparison to burger king.

# %% [markdown]
# In order to anwser this question, I am goig to perform an observational study.
# More specifically, this will be a rhetrospective observational study because
# the data im using has already been created. Some biases in this data set is the fact that data set 2 and dataset 1 only use 50 responses and I used convinent sampling to get them this ultimatly means that the range of reviews this dataset can be used for is limited to itself.

# %%
import pandas as pd
import seaborn as sns

# Use quotes around the filename to make it a string
dataset = pd.read_csv("burgerking.csv")  # Added pd.read_csv() and quotes around filename

# %%
dataset.head()
dataset.head()
# Out:
#         Name          Date                                             Review  \
# 0     Jay B.  Oct 24, 2024  The food and service tonight was absolutely am...
# 1  Stacey K.  Jan 22, 2025  The bacon melt sandwich at this Burger King is...
# 2   Tyler D.  Apr 23, 2021  TERRIBLE customer service. There is a lady who...
# 3      M. S.  Nov 30, 2020  While the service is good and the employees ar...
# 4    Juan J.   Apr 7, 2020  Where did they find all of the low quality wom...
#
#    Stars
# 0      5
# 1      5
# 2      1
# 3      3
# 4      1

# %%
data = [
    {"Name": "Alex T.", "Review": "Food was hot and perfectly cooked. McDonald’s got it right tonight.", "Stars": 5, "Date": "May 12, 2024"},
    {"Name": "Maria S.", "Review": "Burger was dry, fries soggy. Disappointing experience.", "Stars": 2, "Date": "Sep 3, 2023"},
    {"Name": "John D.", "Review": "Staff were super friendly, drive-thru was fast. Overall great experience.", "Stars": 5, "Date": "Mar 15, 2025"},
    {"Name": "Emily L.", "Review": "Coffee tasted burnt. Not coming back for the morning pick up.", "Stars": 1, "Date": "Jul 21, 2022"},
    {"Name": "Kevin W.", "Review": "Nuggets were good but the dipping sauces were missing.", "Stars": 3, "Date": "Jan 10, 2024"},
    {"Name": "Olivia B.", "Review": "Love their breakfast menu. Egg McMuffin was fresh and delicious.", "Stars": 5, "Date": "Nov 5, 2023"},
    {"Name": "Mark R.", "Review": "Waited 20 minutes for a simple order thanks to a car ahead who messed up everything.", "Stars": 2, "Date": "Mar 2, 2021"},
    {"Name": "Natalie K.", "Review": "McFlurry was too sweet, but good nonetheless.", "Stars": 3, "Date": "Dec 17, 2023"},
    {"Name": "Samuel P.", "Review": "Best fries I’ve had in a while. Crispy and salted just right.", "Stars": 5, "Date": "Aug 8, 2024"},
    {"Name": "Dana H.", "Review": "Drive-thru messed up my order. They fixed it but the wait was long.", "Stars": 3, "Date": "Feb 28, 2022"},
    {"Name": "Brian Z.", "Review": "Clean store, friendly service, food was exactly what I ordered.", "Stars": 5, "Date": "Jun 1, 2025"},
    {"Name": "Carmen F.", "Review": "They forgot my drink and didn’t notice until I got home.", "Stars": 2, "Date": "Oct 25, 2024"},
    {"Name": "Tyler G.", "Review": "The new sandwich is okay but overpriced.", "Stars": 3, "Date": "Apr 4, 2023"},
    {"Name": "Lisa Y.", "Review": "Always consistent, love the Big Mac.", "Stars": 5, "Date": "Mar 18, 2024"},
    {"Name": "Gibert O.", "Review": "Restroom was dirty. Not acceptable.", "Stars": 1, "Date": "Jan 30, 2022"},
    {"Name": "Fiona S.", "Review": "The staff tried to help even though they were swamped. Appreciated the effort.", "Stars": 4, "Date": "Jul 2, 2023"},
    {"Name": "Eduardo M.", "Review": "Spilled drink in my bag — wrapper was loose.", "Stars": 2, "Date": "Nov 12, 2021"},
    {"Name": "Alexis P.", "Review": "Apple pie was amazing. Nostalgia tastes good.", "Stars": 5, "Date": "May 8, 2025"},
    {"Name": "Jordan C.", "Review": "Fries cold, burger lukewarm.", "Stars": 2, "Date": "Sep 19, 2022"},
    {"Name": "Priscilla N.", "Review": "Good Happy Meal for kids. They liked the toy and food.", "Stars": 4, "Date": "Jun 30, 2024"},
    {"Name": "Omar W.", "Review": "McCafe latte was perfect, but the cashier seemed grumpy.", "Stars": 4, "Date": "Dec 14, 2023"},
    {"Name": "Beth G.", "Review": "Ordered via app; they messed up the pick-up time.", "Stars": 2, "Date": "Mar 27, 2025"},
    {"Name": "Christopher T.", "Review": "Friendly manager, apologized for wait, gave coupon.", "Stars": 5, "Date": "Aug 3, 2024"},
    {"Name": "Vanessa R.", "Review": "Bacon was stale. Whole thing lacked flavor.", "Stars": 1, "Date": "Oct 9, 2022"},
    {"Name": "Roger J.", "Review": "Loved the new addition to menu. Will order again.", "Stars": 5, "Date": "Feb 1, 2023"},
    {"Name": "Selena H.", "Review": "Breakfast wrap good, but hash browns underdone.", "Stars": 3, "Date": "Jul 14, 2021"},
    {"Name": "Derek L.", "Review": "Drive-thru was closed outside hours listed. Frustrating.", "Stars": 1, "Date": "Nov 29, 2024"},
    {"Name": "Tanya F.", "Review": "Great value for what you get.", "Stars": 4, "Date": "Mar 5, 2022"},
    {"Name": "August N.", "Review": "Customer service was amazing. Felt welcomed.", "Stars": 5, "Date": "Jan 15, 2025"},
    {"Name": "Walter P.", "Review": "Nuggets burned. Took them back. Got replacements.", "Stars": 2, "Date": "Jun 17, 2023"},
    {"Name": "Molly Z.", "Review": "Good salad option. Healthy feel.", "Stars": 4, "Date": "Apr 28, 2024"},
    {"Name": "Sean C.", "Review": "Poor lighting inside, hard to see menu.", "Stars": 2, "Date": "Dec 2, 2022"},
    {"Name": "Yvette Q.", "Review": "Big Macs are still great.", "Stars": 5, "Date": "Sep 8, 2024"},
    {"Name": "Preston D.", "Review": "Soda machine was broken.", "Stars": 1, "Date": "Mar 21, 2021"},
    {"Name": "Brenda S.", "Review": "Friendly young staff. Appreciated their cheer.", "Stars": 4, "Date": "Nov 7, 2023"},
    {"Name": "Mitchell K.", "Review": "Milkshake too watery. Ice cream flavor was okay though.", "Stars": 2, "Date": "Feb 24, 2025"},
    {"Name": "Shirley M.", "Review": "I love McDonald’s fries. Perfect level of crisp.", "Stars": 5, "Date": "Aug 30, 2024"},
    {"Name": "Curtis O.", "Review": "Nuggets sauce missing. Forgot extras.", "Stars": 2, "Date": "Jan 19, 2022"},
    {"Name": "Janice E.", "Review": "Friendly service, super fast.", "Stars": 5, "Date": "Jul 6, 2023"},
    {"Name": "Leo V.", "Review": "Breakfast biscuits were soggy.", "Stars": 1, "Date": "Oct 31, 2021"},
    {"Name": "Gloria H.", "Review": "Useful app ordering. Saved time.", "Stars": 5, "Date": "May 16, 2024"},
    {"Name": "Quentin B.", "Review": "Too much salt on fries.", "Stars": 2, "Date": "Dec 21, 2022"},
    {"Name": "Monica U.", "Review": "Manager apologized for mix-up and comp’d a meal.", "Stars": 5, "Date": "Mar 30, 2025"},
    {"Name": "Indira L.", "Review": "Drive-thru speaker was muffled. Hard to hear order.", "Stars": 2, "Date": "Nov 3, 2023"},
    {"Name": "Fabian J.", "Review": "Cheeseburger small, not filling.", "Stars": 2, "Date": "Jul 12, 2022"},
    {"Name": "Nikki T.", "Review": "Apple slices fresh; good for kids.", "Stars": 4, "Date": "Mar 9, 2024"},
    {"Name": "Conrad Z.", "Review": "Often great, tonight mediocre.", "Stars": 3, "Date": "Jan 27, 2021"},
    {"Name": "Danielle F.", "Review": "Tried their digital kiosks — very easy, less wait.", "Stars": 5, "Date": "Oct 6, 2024"},
    {"Name": "Omar Q.", "Review": "Burger bun stale, unappetizing.", "Stars": 1, "Date": "Apr 1, 2022"},
    {"Name": "Tasha W.", "Review": "The staff remembered my name. Nice touch.", "Stars": 5, "Date": "Aug 18, 2024"},
]

# %%
data2 = [
    {"Name": "Sarah M.", "Review": "Whopper was juicy and delicious, fries were crispy.", "Stars": 5, "Date": "Apr 10, 2024"},
    {"Name": "James T.", "Review": "Drive-thru was slow but food was fresh.", "Stars": 4, "Date": "May 2, 2023"},
    {"Name": "Lisa R.", "Review": "Burger was cold, not happy with the service.", "Stars": 2, "Date": "Jun 15, 2022"},
    {"Name": "Michael S.", "Review": "Loved the new plant-based burger option!", "Stars": 5, "Date": "Jan 9, 2024"},
    {"Name": "Jessica P.", "Review": "Fries were soggy, needs improvement.", "Stars": 2, "Date": "Dec 20, 2023"},
    {"Name": "David K.", "Review": "Staff was friendly and efficient.", "Stars": 4, "Date": "Aug 3, 2024"},
    {"Name": "Angela L.", "Review": "Burger was too salty.", "Stars": 2, "Date": "Nov 11, 2022"},
    {"Name": "Chris B.", "Review": "Perfect onion rings every time.", "Stars": 5, "Date": "Mar 5, 2023"},
    {"Name": "Natalie D.", "Review": "Long wait but worth it for the flame-grilled taste.", "Stars": 4, "Date": "Feb 14, 2024"},
    {"Name": "Ryan H.", "Review": "Order was incorrect, had to go back.", "Stars": 2, "Date": "Jul 19, 2021"},
    {"Name": "Karen J.", "Review": "Kids loved the kids meal toys!", "Stars": 5, "Date": "Sep 25, 2023"},
    {"Name": "Steven M.", "Review": "Drive-thru speaker was hard to hear.", "Stars": 3, "Date": "Oct 13, 2022"},
    {"Name": "Patricia W.", "Review": "Burger was overcooked.", "Stars": 1, "Date": "Dec 7, 2023"},
    {"Name": "Brandon F.", "Review": "The new spicy chicken sandwich is amazing!", "Stars": 5, "Date": "Jun 9, 2024"},
    {"Name": "Amy C.", "Review": "Service was friendly but slow.", "Stars": 3, "Date": "Apr 27, 2023"},
    {"Name": "George N.", "Review": "Fries were perfectly salted.", "Stars": 5, "Date": "Mar 17, 2025"},
    {"Name": "Helen T.", "Review": "Restrooms were dirty.", "Stars": 1, "Date": "Jan 29, 2022"},
    {"Name": "Timothy G.", "Review": "Good value meal for the price.", "Stars": 4, "Date": "Oct 4, 2024"},
    {"Name": "Megan S.", "Review": "Burger was dry, disappointed.", "Stars": 2, "Date": "May 15, 2023"},
    {"Name": "Jeffrey A.", "Review": "Flame-grilled flavor can’t be beat!", "Stars": 5, "Date": "Nov 2, 2024"},
    {"Name": "Rachel B.", "Review": "Order came with missing items.", "Stars": 2, "Date": "Sep 10, 2022"},
    {"Name": "Eric K.", "Review": "Good seating area and clean environment.", "Stars": 4, "Date": "Jan 20, 2023"},
    {"Name": "Diana V.", "Review": "Breakfast menu needs more options.", "Stars": 3, "Date": "Feb 11, 2024"},
    {"Name": "Adam Y.", "Review": "Excellent customer service!", "Stars": 5, "Date": "Apr 8, 2025"},
    {"Name": "Linda M.", "Review": "Burger buns were stale.", "Stars": 1, "Date": "Mar 3, 2022"},
    {"Name": "Benjamin P.", "Review": "Nice atmosphere and quick service.", "Stars": 4, "Date": "Aug 21, 2023"},
    {"Name": "Olivia J.", "Review": "Fries were cold when served.", "Stars": 2, "Date": "Jul 7, 2023"},
    {"Name": "Kevin W.", "Review": "Great value on combo meals.", "Stars": 5, "Date": "Oct 28, 2024"},
    {"Name": "Stephanie R.", "Review": "Order was mixed up but quickly fixed.", "Stars": 4, "Date": "May 9, 2022"},
    {"Name": "Jason C.", "Review": "I love the Whopper. Always consistent.", "Stars": 5, "Date": "Jun 14, 2024"},
    {"Name": "Monica H.", "Review": "Parking lot was messy.", "Stars": 2, "Date": "Feb 19, 2023"},
    {"Name": "Patrick L.", "Review": "Friendly staff and quick service.", "Stars": 5, "Date": "Apr 22, 2025"},
    {"Name": "Jessica F.", "Review": "Drinks machine was broken.", "Stars": 1, "Date": "Nov 13, 2022"},
    {"Name": "Sean E.", "Review": "Burger was tasty but fries lacked seasoning.", "Stars": 3, "Date": "Jan 8, 2023"},
    {"Name": "Emily N.", "Review": "Great for a quick lunch.", "Stars": 4, "Date": "Jul 30, 2024"},
    {"Name": "Robert D.", "Review": "Drive-thru was closed early unexpectedly.", "Stars": 1, "Date": "Sep 16, 2022"},
    {"Name": "Hannah G.", "Review": "Loved the soft serve ice cream!", "Stars": 5, "Date": "Mar 12, 2023"},
    {"Name": "Carlos S.", "Review": "Order arrived late but food was still hot.", "Stars": 4, "Date": "Oct 20, 2024"},
    {"Name": "Vanessa K.", "Review": "Chicken nuggets were dry.", "Stars": 2, "Date": "Apr 2, 2023"},
    {"Name": "Dennis M.", "Review": "Consistently good experience.", "Stars": 5, "Date": "Jun 5, 2025"},
    {"Name": "Theresa Q.", "Review": "Poor communication from staff.", "Stars": 2, "Date": "Feb 14, 2022"},
    {"Name": "Gregory O.", "Review": "Burger was amazing and juicy.", "Stars": 5, "Date": "Jan 25, 2024"},
    {"Name": "Jasmine T.", "Review": "Long wait times, busy place.", "Stars": 3, "Date": "Aug 6, 2023"},
    {"Name": "Paul W.", "Review": "Loved the flame-grilled taste, will return.", "Stars": 5, "Date": "Sep 4, 2024"},
    {"Name": "Katherine Z.", "Review": "Order was cold and soggy.", "Stars": 1, "Date": "Nov 30, 2022"},
    {"Name": "Ethan V.", "Review": "Friendly staff and clean seating area.", "Stars": 4, "Date": "May 23, 2023"},
    {"Name": "Melissa J.", "Review": "Not impressed with the new menu items.", "Stars": 2, "Date": "Mar 29, 2023"},
    {"Name": "Jacob H.", "Review": "Great flame-grilled flavor, loved the burger.", "Stars": 5, "Date": "Feb 10, 2025"},
    {"Name": "Samantha P.", "Review": "Drive-thru messed up my order.", "Stars": 2, "Date": "Oct 15, 2024"},
    {"Name": "Aaron F.", "Review": "Excellent food and fast service.", "Stars": 5, "Date": "Jul 11, 2023"},
]

# %%
data2 = pd.DataFrame(data2)

# %%
test = pd.DataFrame(data)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    50 non-null     object
#  1   Review  50 non-null     object
#  2   Stars   50 non-null     int64
#  3   Date    50 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.7+ KB

# %%
print(f"Burger King dataset rows: {len(bk_df)}")
print(f"McDonald's dataset rows: {len(mcd_df)}")
# Out:
# Burger King dataset rows: 2
# McDonald's dataset rows: 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Your McDonald's data (shortened here for example; replace with your full data)
mcdonalds_data = [
    {"Name": "Alex T.", "Review": "Food was hot and perfectly cooked.", "Stars": 5, "Date": "May 12, 2024"},
    {"Name": "Maria S.", "Review": "Burger was dry.", "Stars": 2, "Date": "Sep 3, 2023"},
    {"Name": "John D.", "Review": "Drive-thru was fast.", "Stars": 5, "Date": "Mar 15, 2025"},
    # ... (add all McDonald's reviews)
]

# Your Burger King data (shortened here for example; replace with your full data)
burger_king_data = [
    {"Name": "Sarah M.", "Review": "Whopper was juicy and delicious.", "Stars": 5, "Date": "Apr 10, 2024"},
    {"Name": "James T.", "Review": "Drive-thru was slow but food was fresh.", "Stars": 4, "Date": "May 2, 2023"},
    {"Name": "Lisa R.", "Review": "Burger was cold.", "Stars": 2, "Date": "Jun 15, 2022"},
    # ... (add all Burger King reviews)
]

# Convert to DataFrame
df_mcd = pd.DataFrame(mcdonalds_data)
df_bk = pd.DataFrame(burger_king_data)

# Convert date to datetime with format='mixed' to handle different date formats
# This tells pandas to infer the format for each date individually
df_mcd['Date'] = pd.to_datetime(df_mcd['Date'], format='mixed')
df_mcd['Year'] = df_mcd['Date'].dt.year

df_bk['Date'] = pd.to_datetime(df_bk['Date'], format='mixed')
df_bk['Year'] = df_bk['Date'].dt.year

# Calculate average stars per year for each
mcd_avg = df_mcd.groupby('Year')['Stars'].mean()
bk_avg = df_bk.groupby('Year')['Stars'].mean()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(mcd_avg.index, mcd_avg.values, marker='o', label="McDonald's")
plt.plot(bk_avg.index, bk_avg.values, marker='s', label="Burger King")

plt.title('Average Star Rating per Year')
plt.xlabel('Year')
plt.ylabel('Average Stars')
plt.xticks(sorted(set(mcd_avg.index) | set(bk_avg.index)))  # Combine all years for x ticks
plt.ylim(0, 5)
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example: Convert lists of dicts to DataFrames (replace with your actual data)
data = pd.DataFrame(data)   
data2 = pd.DataFrame(data2)

# Now you can access the 'Stars' column
total_stars_data = data['Stars'].sum()
total_stars_data2 = data2['Stars'].sum()

# Create DataFrame for plotting
totals = pd.DataFrame({
    'Dataset': ['data', 'data2'],
    'Total Stars': [total_stars_data, total_stars_data2]
})

# Plot
totals.plot(kind='bar', x='Dataset', y='Total Stars', legend=False)
plt.ylabel('Total Stars')
plt.title('Total Stars in Datasets')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Your McDonald's data (shortened here for example; replace with your full data)
mcdonalds_data = [
    {"Name": "Alex T.", "Review": "Food was hot and perfectly cooked.", "Stars": 5, "Date": "May 12, 2024"},
    {"Name": "Maria S.", "Review": "Burger was dry.", "Stars": 2, "Date": "Sep 3, 2023"},
    {"Name": "John D.", "Review": "Drive-thru was fast.", "Stars": 5, "Date": "Mar 15, 2025"},
    # ... (add all McDonald's reviews)
]

# Your Burger King data (shortened here for example; replace with your full data)
burger_king_data = [
    {"Name": "Sarah M.", "Review": "Whopper was juicy and delicious.", "Stars": 5, "Date": "Apr 10, 2024"},
    {"Name": "James T.", "Review": "Drive-thru was slow but food was fresh.", "Stars": 4, "Date": "May 2, 2023"},
    {"Name": "Lisa R.", "Review": "Burger was cold.", "Stars": 2, "Date": "Jun 15, 2022"},
    # ... (add all Burger King reviews)
]

# Convert to DataFrame
df_mcd = pd.DataFrame(mcdonalds_data)
df_bk = pd.DataFrame(burger_king_data)

# Sum total stars
mcd_total_stars = df_mcd['Stars'].sum()
bk_total_stars = df_bk['Stars'].sum()

# Calculate ratio of total stars
if bk_total_stars > 0:
    star_ratio = mcd_total_stars / bk_total_stars
    print(f"McDonald's has {star_ratio:.1f}x as many total Yelp stars as Burger King.")
else:
    print("Burger King has 0 total stars, cannot compute ratio.")

# Convert date to datetime
df_mcd['Date'] = pd.to_datetime(df_mcd['Date'], format='mixed')
df_mcd['Year'] = df_mcd['Date'].dt.year

df_bk['Date'] = pd.to_datetime(df_bk['Date'], format='mixed')
df_bk['Year'] = df_bk['Date'].dt.year

# Calculate average stars per year
mcd_avg = df_mcd.groupby('Year')['Stars'].mean()
bk_avg = df_bk.groupby('Year')['Stars'].mean()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(mcd_avg.index, mcd_avg.values, marker='o', label="McDonald's")
plt.plot(bk_avg.index, bk_avg.values, marker='s', label="Burger King")

plt.title('Average Star Rating per Year')
plt.xlabel('Year')
plt.ylabel('Average Stars')
plt.xticks(sorted(set(mcd_avg.index) | set(bk_avg.index)))
plt.ylim(0, 5)
plt.legend()
plt.grid(True)

# Optional: annotate plot with total star ratio
plt.text(0.5, 4.7, f"McDonald's has {star_ratio:.1f}x as many total stars",
         transform=plt.gca().transAxes, fontsize=10, color='gray')

plt.show()
# Out:
# McDonald's has 1.1x as many total Yelp stars as Burger King.
